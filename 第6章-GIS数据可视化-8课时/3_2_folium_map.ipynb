# %% [markdown]
# ### **gis数据线上地图可视化**

# %%
import folium
import pandas
import geopandas as gpd

# %%
path_kunming_vec = 'data/Section-6/kunming_districts.geojson'

# %%
### 利用开源库geopandas打开矢量数据，参考https://geopandas.org/en/stable/
kunming_vec_gpd = gpd.read_file(path_kunming_vec)
kunming_vec_gpd
# Out:
#    dt_adcode    dt_name ct_adcode  ct_name pr_adcode cn_adcode    area(km2)  \
# 0     530102      wuhua    530100  kunming    530000    100000   377.995979
# 1     530103    panlong    530100  kunming    530000    100000   864.295297
# 2     530111     guandu    530100  kunming    530000    100000   638.333617
# 3     530112     xishan    530100  kunming    530000    100000   897.396732
# 4     530113  dongchuan    530100  kunming    530000    100000  1866.117588
# 5     530114  chenggong    530100  kunming    530000    100000   499.363964
# 6     530115    jinning    530100  kunming    530000    100000  1338.564497
# 7     530124      fumin    530100  kunming    530000    100000   994.675119
# 8     530125    yiliang    530100  kunming    530000    100000  1914.092175
# 9     530126     shilin    530100  kunming    530000    100000  1681.342856
# 10    530127   songming    530100  kunming    530000    100000   828.475686
# 11    530128     luquan    530100  kunming    530000    100000  4227.345074
# 12    530129    xundian    530100  kunming    530000    100000  3598.342900
# 13    530181     anning    530100  kunming    530000    100000  1301.006260
#
#                                              geometry
# 0   MULTIPOLYGON (((102.71331 25.13651, 102.71547 ...
# 1   MULTIPOLYGON (((102.71668 25.04473, 102.71663 ...
# 2   MULTIPOLYGON (((102.71717 25.03341, 102.71792 ...
# 3   MULTIPOLYGON (((102.50726 24.86019, 102.50689 ...
# 4   MULTIPOLYGON (((102.80340 26.30291, 102.80537 ...
# 5   MULTIPOLYGON (((102.85321 24.69792, 102.85168 ...
# 6   MULTIPOLYGON (((102.73979 24.81731, 102.74137 ...
# 7   MULTIPOLYGON (((102.63768 25.36767, 102.64085 ...
# 8   MULTIPOLYGON (((103.27379 25.25786, 103.27332 ...
# 9   MULTIPOLYGON (((103.66655 24.72420, 103.66542 ...
# 10  MULTIPOLYGON (((102.95307 25.25274, 102.95301 ...
# 11  MULTIPOLYGON (((102.45946 25.42993, 102.46137 ...
# 12  MULTIPOLYGON (((103.54505 25.58380, 103.54325 ...
# 13  MULTIPOLYGON (((102.26544 24.55692, 102.26724 ...

# %% [markdown]
# #### 矢量数据显示

# %%
map = folium.Map(location=[24.83, 102.84], 
            tiles='https://webrd02.is.autonavi.com/appmaptile?lang=zh_en&size=1&scale=1&style=8&x={x}&y={y}&z={z}',
            attr='高德地图-中英文版',
            zoom_start=8)

folium.GeoJson(data=path_kunming_vec, 
               tooltip=folium.GeoJsonTooltip(fields=['dt_name']),
               ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a12c7de8d77a0a789463151ac642025 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a12c7de8d77a0a789463151ac642025&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a12c7de8d77a0a789463151ac642025 = L.map(
#                 &quot;map_4a12c7de8d77a0a789463151ac642025&quot;,
#                 {
#                     center: [24.83, 102.84],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be3ef4ff76dc2ade6a8a1caf68e4fca5 = L.tileLayer(
#                 &quot;https://webrd02.is.autonavi.com/appmaptile?lang=zh_en\u0026size=1\u0026scale=1\u0026style=8\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7\
# %% [markdown]
# #### 基于矢量数据的统计数据可视化
# 地图分级着色folium.Choropleth()
# 参考：https://python-visualization.github.io/folium/modules.html

# %% [markdown]
# 1. 面积可视化

# %%
map = folium.Map(location=[24.83, 102.84], 
        tiles='https://webrd02.is.autonavi.com/appmaptile?lang=zh_en&size=1&scale=1&style=8&x={x}&y={y}&z={z}',
        attr='高德地图-中英文版',
        zoom_start=8)

folium.Choropleth(\
            geo_data=path_kunming_vec,                         #选择json
            data = kunming_vec_gpd,
            columns = ['dt_name','area(km2)'],           # 列，第一个为属性，第二个为值
            key_on = 'feature.properties.dt_name',       # 匹配到 geojson
            fill_color = 'YlGn',                 # 颜色
            fill_opacity=0.8,
            legend_name = '面积'                  # 图例  
            ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed8631a0436b31a75ca1adf2dc44570e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed8631a0436b31a75ca1adf2dc44570e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed8631a0436b31a75ca1adf2dc44570e = L.map(
#                 &quot;map_ed8631a0436b31a75ca1adf2dc44570e&quot;,
#                 {
#                     center: [24.83, 102.84],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2401ce992615f7def70bc4879659c41c = L.tileLayer(
#                 &quot;https://webrd02.is.autonavi.com/appmaptile?lang=zh_en\u0026size=1\u0026scale=1\u0026style=8\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7\u5730\u56fe-\u4e2d\u82f1\u6587\u7248&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ed8631a0436b31a75ca1adf2dc44570e);
#
#
#             var choropleth_4e900d0a4d24ba80ffeb810ada6ac807 = L.featureGroup(
#                 {}
#             ).addTo(map_ed8631a0436b31a75ca1adf2dc44570e);
#
#
#         function geo_json_f6728d431061796e0cd7426aced0babb_styler(feature) {
#             switch(feature.properties.dt_adcode) {
#                 case &quot;530113&quot;: case &quot;530125&quot;: case &quot;530126&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;530115&quot;: case &quot;530181&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;530128&quot;: case &quot;530129&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_f6728d431061796e0cd7426aced0babb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f6728d431061796e0cd7426aced0babb = L.geoJson(null, {
#                 onEachFeature: geo_json_f6728d431061796e0cd7426aced0babb_onEachFeature,
#
#                 style: geo_json_f6728d431061796e0cd7426aced0babb_styler,
#         });
#
#         function geo_json_f6728d431061796e0cd7426aced0babb_add (data) {
#             geo_json_f6728d431061796e0cd7426aced0babb
#                 .addData(data)
#                 .addTo(choropleth_4e900d0a4d24ba80ffeb810ada6ac807);
#         }
#             geo_json_f6728d431061796e0cd7426aced0babb_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[102.713306, 25.136515], [102.715473, 25.137243], [102.718014, 25.132135], [102.717876, 25.128678], [102.718119, 25.123739], [102.71885, 25.121694], [102.71912, 25.121421], [102.719703, 25.120299], [102.720528, 25.119658], [102.721433, 25.119367], [102.722876, 25.119076], [102.723921, 25.119106], [102.724629, 25.119148], [102.725112, 25.119327], [102.725587, 25.119217], [102.725537, 25.118238], [102.726277, 25.118004], [102.72677, 25.117925], [102.727328, 25.117809], [102.727665, 25.117638], [102.727768, 25.117585], [102.730694, 25.117628], [102.732115, 25.119994], [102.733644, 25.122731], [102.734408, 25.123695], [102.735598, 25.125591], [102.736558, 25.125009], [102.738373, 25.127778], [102.740796, 25.125879], [102.743625, 25.123812], [102.744677, 25.122908], [102.745526, 25.121981], [102.746446, 25.120838], [102.747135, 25.119983], [102.748399, 25.118251], [102.746746, 25.117756], [102.743381, 25.116565], [102.742954, 25.116345], [102.742611, 25.11617], [102.742201, 25.115691], [102.740325, 25.112577], [102.740225, 25.112268], [102.740017, 25.109963], [102.739538, 25.106398], [102.738956, 25.102183], [102.738481, 25.100312], [102.738118, 25.099253], [102.737635, 25.097931], [102.736851, 25.095698], [102.736372, 25.094295], [102.735983, 25.093818], [102.735471, 25.093691], [102.732891, 25.093551], [102.731927, 25.093478], [102.731872, 25.093446], [102.731255, 25.093083], [102.730942, 25.092671], [102.729099, 25.09082], [102.726439, 25.088144], [102.726152, 25.087712], [102.725935, 25.087327], [102.724804, 25.084555], [102.723979, 25.082195], [102.723822, 25.081802], [102.723535, 25.081189], [102.723318, 25.080907], [102.723013, 25.080562], [102.716988, 25.076574], [102.716527, 25.076187], [102.716144, 25.075686], [102.7147, 25.07301], [102.714039, 25.07177], [102.7139, 25.071388], [102.713856, 25.071092], [102.713839, 25.070777], [102.713987, 25

# %% [markdown]
# 2. 人口可视化
#  （五华114万，盘龙98万，官渡160万，西山96万，东川26万, 呈贡64万，晋宁34万，富民14, 宜良38万，石林24，嵩明41万，禄劝37万, 寻甸46万，安宁48）

# %%
### 定义pandas.Dataframe()格式的人口数据
population_dict = {'dt_name': ['wuhua', 'panlong', 'guandu', 'xishan', 'dongchuan', 'chenggong', 'jinning', 'fumin', 'yiliang', 'shilin', 'songming', 'luquan', 'xundian', 'anning'], 
                   'population': [114, 98, 160, 26, 26, 64, 34, 14, 38, 24, 41, 37, 46, 48]
                   }    
population_dict = pandas.DataFrame.from_dict(population_dict)
population_dict
# Out:
#       dt_name  population
# 0       wuhua         114
# 1     panlong          98
# 2      guandu         160
# 3      xishan          26
# 4   dongchuan          26
# 5   chenggong          64
# 6     jinning          34
# 7       fumin          14
# 8     yiliang          38
# 9      shilin          24
# 10   songming          41
# 11     luquan          37
# 12    xundian          46
# 13     anning          48

# %%
map = folium.Map(location=[24.83, 102.84], 
            tiles='https://webrd02.is.autonavi.com/appmaptile?lang=zh_en&size=1&scale=1&style=8&x={x}&y={y}&z={z}',
            attr='高德地图-中英文版',
            zoom_start=8)

folium.Choropleth(path_kunming_vec,                         #选择json
           data = population_dict,
           columns = ['dt_name','population'],       # 列，第一个为key，第二个为value
           key_on = 'feature.properties.dt_name',       # 匹配到json
           fill_color = 'PuBu',                      # 颜色
           fill_opacity=0.8,
           legend_name = '人口'                      # 图例  
            ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7574b931cbc0ff73cc583ff5ad79bb52 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7574b931cbc0ff73cc583ff5ad79bb52&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7574b931cbc0ff73cc583ff5ad79bb52 = L.map(
#                 &quot;map_7574b931cbc0ff73cc583ff5ad79bb52&quot;,
#                 {
#                     center: [24.83, 102.84],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49193ab31829a85b3a756c897e42f15a = L.tileLayer(
#                 &quot;https://webrd02.is.autonavi.com/appmaptile?lang=zh_en\u0026size=1\u0026scale=1\u0026style=8\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7\u5730\u56fe-\u4e2d\u82f1\u6587\u7248&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7574b931cbc0ff73cc583ff5ad79bb52);
#
#
#             var choropleth_7979d4bb05b900d1e3d49bab7e5d21fe = L.featureGroup(
#                 {}
#             ).addTo(map_7574b931cbc0ff73cc583ff5ad79bb52);
#
#
#         function geo_json_34b5a862bab4545ae1c1fd607b6a3629_styler(feature) {
#             switch(feature.properties.dt_adcode) {
#                 case &quot;530102&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2b8cbe&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;530103&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#74a9cf&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;530111&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#045a8d&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;530114&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a6bddb&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;530127&quot;: case &quot;530129&quot;: case &quot;530181&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d0d1e6&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_34b5a862bab4545ae1c1fd607b6a3629_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_34b5a862bab4545ae1c1fd607b6a3629 = L.geoJson(null, {
#                 onEachFeature: geo_json_34b5a862bab4545ae1c1fd607b6a3629_onEachFeature,
#
#                 style: geo_json_34b5a862bab4545ae1c1fd607b6a3629_styler,
#         });
#
#         function geo_json_34b5a862bab4545ae1c1fd607b6a3629_add (data) {
#             geo_json_34b5a862bab4545ae1c1fd607b6a3629
#                 .addData(data)
#                 .addTo(choropleth_7979d4bb05b900d1e3d49bab7e5d21fe);
#         }
#             geo_json_34b5a862bab4545ae1c1fd607b6a3629_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[102.713306, 25.136515], [102.715473, 25.137243], [102.718014, 25.132135], [102.717876, 25.128678], [102.718119, 25.123739], [102.71885, 25.121694], [102.71912, 25.121421], [102.719703, 25.120299], [102.720528, 25.119658], [102.721433, 25.119367], [102.722876, 25.119076], [102.723921, 25.119106], [102.724629, 25.119148], [102.725112, 25.119327], [102.725587, 25.119217], [102.725537, 25.118238], [102.726277, 25.118004], [102.72677, 25.117925], [102.727328, 25.117809], [102.727665, 25.117638], [102.727768, 25.117585], [102.730694, 25.117628], [102.732115, 25.119994], [102.733644, 25.122731], [102.734408, 25.123695], [102.735598, 25.125591], [102.736558, 25.125009], [102.738373, 25.127778], [102.740796, 25.125879], [102.743625, 25.123812], [102.744677, 25.122908], [102.745526, 25.121981], [102.746446, 25.120838], [102.747135, 25.119983], [102.748399, 25.118251], [102.746746, 25.117756], [102.743381, 25.116565], [102.742954, 25.116345], [102.742611, 25.11617], [102.742201, 25.115691], [102.740325, 25.112577], [102.740225, 25.112268], [102.740017, 25.109963], [102.739538, 25.106398], [102.738956, 25.102183], [102.738481, 25.100312], [102.738118, 25.099253], [102.737635, 25.097931], [102.736851, 25.095698], [102.736372, 25.094295], [102.735983, 25.093818], [102.735471, 25.093691], [102.732891, 25.093551], [102.731927, 25.093478], [102.731872, 25.093446], [102.731255, 25.093083], [102.730942, 25.092671], [102.729099, 25.09082], [102.726439, 25.088144],

# %% [markdown]
# #### 章节作业
# 利用python开源库制作云南大学地标区域（如图书馆、玫瑰园等）线上地图。要求标注云大呈贡校区范围，地标区域不得少于5处，线上地图简洁规范、包含信息充分，用户操作体验良好。

# %% [markdown]
# ###
