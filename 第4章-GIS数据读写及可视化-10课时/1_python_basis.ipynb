# %% [markdown]
# ### **Python编程风格介绍**

# %% [markdown]
# ### 1、基本数据类型
# ##### python中7种数据类型：<u>Bool（布尔）、Number（数字）、String（字符串）、List（列表）、Dictionary（字典）</u>、Tuple（元组）、Set（集合）

# %%
print('bool:', True, False)   ### bool
print('number:,', 1)   ### number
print('string:,', 'hellow world')   ### string
print('list:,', [18, 28, 15])    ### list
print('dictionary:,', {'小张': 80, '小李':85, '小周': 78})   ### string
# Out:
# bool: True False
# number:, 1
# string:, hellow world
# list:, [18, 28, 15]
# dictionary:, {'小张': 80, '小李': 85, '小周': 78}

# %% [markdown]
# ### 2、变量与赋值

# %%
a = 1
b = 4 
c = [1,2,3]
print(a, b)
print(c[1])
# Out:
# 1 4
# 2

# %% [markdown]
# ### 3、条件判断
# #### python通过if...else...

# %%
### 判断成绩优（>=90），良（>=70,<90）,差（<70）
score = 67
if score >= 90:
  print('成绩为优秀')
elif score >= 70 and score<90:
  print('成绩为良好')
else :
  print('成绩为差')
# Out:
# 成绩为差

# %% [markdown]
# ### 4、循环

# %%
### 获得成绩为优秀的同学个数
scores=[70,76,84,83,94,91,93,79,81,90]
num = 0
for score in scores:
  # print(score)
  if score >= 90:
    num=num+1
print('获得成绩为优秀的同学个数为：', num)
# Out:
# 获得成绩为优秀的同学个数为： 4

# %% [markdown]
# ### 5、函数

# %%
### 自动统计出超出一给定分数的同学人数。
scores=[70,76,84,83,94,91,93,79,81,90]
def num_higher(s, s_high=90):
  num = 0
  for score in s:
    # print(score)
    if score >= s_high:
      num=num+1
  return num 

num = num_higher(s=scores, s_high=80)
print('超过给定分数的同学人数为：', num)
# Out:
# 超过给定分数的同学人数为： 7

# %% [markdown]
# ### 6、模块

# %%
from python_module import num_higher_m
scores=[70,76,84,83,94,91,93,79,81,90]
num = num_higher_m(ss=scores, s=80)
print('超过给定分数的同学人数为：', num)
# Out:
# 超过给定分数的同学人数为： 7

# %% [markdown]
# ### 7、软件包调用

# %%
import numpy as np 
array = np.array([1,2,3,4,5])
print(array)
arr_mean = np.mean(array)
print(arr_mean)
# Out:
# [1 2 3 4 5]
# 3.0

# %%
# Out:
# <osgeo.ogr.DataSource; proxy of <Swig Object of type 'OGRDataSourceShadow *' at 0x7fc0d8afeed0> >
