# %% [markdown]
# ### 利用matplotlib开源库实现GIS数据统计分析

# %%
import matplotlib.pyplot as plt
import numpy as np
from osgeo import ogr
import matplotlib

# %%
path_kunming_vec = 'data/Section-4/kunming_districts_utm.shp'

# %%
ds = ogr.Open(path_kunming_vec, 1)  ## 0是只读，1是可写
layer = ds.GetLayer(0); 
area_dict = {}
perimeter_dict = {}
for i in range(layer.GetFeatureCount()):
    fea = layer.GetFeature(i)   ## 索引为1开头
    fea_name = fea.GetField('dt_name')
    fea_area = fea.geometry().Area()/1000000
    area_dict[fea_name] = fea_area
    print('Region:', fea_name, ' ', end='')
    print('Area is: ', fea_area)
# Out:
# Region: ???  Area is:  377.9959786954056
# Region: ???  Area is:  864.2952967369265
# Region: ???  Area is:  638.3336172947612
# Region: ???  Area is:  897.3967316211479
# Region: ???  Area is:  1866.1175875336044
# Region: ???  Area is:  499.36396388767395
# Region: ???  Area is:  1338.5644973111575
# Region: ???  Area is:  994.6751193008348
# Region: ???  Area is:  1914.0921754168446
# Region: ???????  Area is:  1681.3428560105956
# Region: ???  Area is:  828.4756858595072
# Region: ?????????  Area is:  4227.345074248606
# Region: ?????????  Area is:  3598.3429000372385
# Region: ???  Area is:  1301.0062596518349

# %% [markdown]
# #### 线图可视化分析

# %%
# Out:
# dict_values([1301.0062596518349, 1681.3428560105956, 3598.3429000372385])

# %%
plt.figure(figsize=(15,4))
# plt.plot(area_dict.keys(), area_dict.values())
plt.plot(area_dict.keys(), area_dict.values(), '-ro', linewidth=3, markersize=10, label='area') 
plt.legend()

# %% [markdown]
# ### 散点图分析

# %%
plt.figure(figsize=(15,4))
plt.scatter(area_dict.keys(), area_dict.values(), s=list(area_dict.values()), color='g')
plt.ylim(0, 5500)
# Out:
# (0.0, 5500.0)

# %% [markdown]
# ### 柱状图

# %%
plt.figure(figsize=(15,4))
plt.bar(area_dict.keys(), area_dict.values(), width=0.5, fc='g', ec='r', label='area')
plt.legend()

# %% [markdown]
# #### 课后作业：利用matplotlib开源库对呈贡区水体、绿地以及其他地表覆盖范围情况进行可视化分析（要求：简洁、且包含足够多信息）。
