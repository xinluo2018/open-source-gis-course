# %% [markdown]
# ### 利用开源制图库folium进行gis数据可视化分析

# %%
import folium
from osgeo import ogr
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd

# %%
path_kunming_vec = 'data/Section_6/kunming_wgs84.geojson'

# %% [markdown]
# #### 矢量数据显示

# %%
map = folium.Map(location=[24.83, 102.84], 
           tiles='https://webst02.is.autonavi.com/appmaptile?style=6&x={x}&y={y}&z={z}',
           attr='高德卫星地图',
           zoom_start=7)
### 
def style_function(feature):
    return {
        "fillOpacity": 0.5,
        'fillColor': 'green',
        'fillOpacity': 0.2,
        'color': 'blue',
    }
folium.GeoJson(data=path_kunming_vec, 
               tooltip=folium.GeoJsonTooltip(fields=['name']),
               style_function=style_function
               ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_040407c0319c2d360fa4b8ccdb41ba34 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_040407c0319c2d360fa4b8ccdb41ba34&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_040407c0319c2d360fa4b8ccdb41ba34 = L.map(
#                 &quot;map_040407c0319c2d360fa4b8ccdb41ba34&quot;,
#                 {
#                     center: [24.83, 102.84],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f48d878cb3accdecc12a154a40fa5a1b = L.tileLayer(
#                 &quot;https://webst02.is.autonavi.com/appmaptile?style=6\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7\u536b\u661f\u5730\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_040407c0319c2d360fa4b8ccdb41ba34);
#
#
#         function geo_json_65ad5c26069896362f2b2dec405b475e_styler(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2};
#             }
#         }
#
#         function geo_json_65ad5c26069896362f2b2dec405b475e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_65ad5c26069896362f2b2dec405b475e = L.geoJson(null, {
#                 onEachFeature: geo_json_65ad5c26069896362f2b2dec405b475e_onEachFeature,
#
#                 style: geo_json_65ad5c26069896362f2b2dec405b475e_styler,
#         });
#
#         function geo_json_65ad5c26069896362f2b2dec405b475e_add (data) {
#             geo_json_65ad5c26069896362f2b2dec405b475e
#                 .addData(data)
#                 .addTo(map_040407c0319c2d360fa4b8ccdb41ba34);
#         }
#             geo_json_65ad5c26069896362f2b2dec405b475e_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[102.235015, 26.188499], [102.235164, 26.188635], [102.236309, 26.1895], [102.23666, 26.189574], [102.238492, 26.190557], [102.24021, 26.192031], [102.241296, 26.194033], [102.242129, 26.19684], [102.242806, 26.199897], [102.243023, 26.204147], [102.243301, 26.209169], [102.243466, 26.214297], [102.243882, 26.215877], [102.244934, 26.217352], [102.246522, 26.218581], [102.249083, 26.21988], [102.25147, 26.220653], [102.252616, 26.221325], [102.253987, 26.222665], [102.255975, 26.223505], [102.257745, 26.223769], [102.260176, 26.224257], [102.262346, 26.224301], [102.265175, 26.223814], [102.268231, 26.223814], [102.272163, 26.223371], [102.276407, 26.223414], [102.281321, 26.223549], [102.284637, 26.223902], [102.288308, 26.224521], [102.292509, 26.225714], [102.297066, 26.228325], [102.299984, 26.22974], [102.302197, 26.230272], [102.306086, 26.230668], [102.309714, 26.230625], [102.311128, 26.230447], [102.312058, 26.230668], [102.312953, 26.231516], [102.313583, 26.232516], [102.314128, 26.234166], [102.314902, 26.234962], [102.316267, 26.235508], [102.320715, 26.237058], [102.322309, 26.237825], [102.326259, 26.239206], [102.328516, 26.240488], [102.329618, 26.240753], [102.33073, 26.240664], [102.33197, 26.24092], [102.33329, 26.241371], [102.336259, 26.243097], [102.339002, 26.244955], [102.340657, 26.24617], [102.342601, 26.246921], [102.344103, 26.247232], [102.345526, 26.247364], [102.347472, 26.247983], [102.349415, 26.249223], [102.351361, 26.251123], [102.353019, 26.25257], [102.354685, 26.254058], [102.358193, 26.258895], [102.359668, 26.260427], [102.361621, 26.261948], [102.363141, 26.264497], [102.365623, 26.268674], [102.367029, 26.270371], [102.369287, 26.2725], [102.372003, 26.27515], [102.373254, 26.276191], [102.374521, 26.277075], [102.375285, 26.277754], [102.37604, 26.278701], [102.378123, 26.281662], [102.379009, 26.283831], [102.380685, 26.286663], [102.381475, 26.289749], [102.382073, 26.29193], [102.382638, 26.293063], [102.387838, 26.297744], [102.391023, 26.299795], [102.392509, 26.300505], [102.394453, 26.300928], [102.398802, 26.300647], [102.400964, 26.300682], [102.403343, 26.301797], [102.406512, 26.302248], [102.409654, 26.302533], [102.412059, 26.303129], [102.413787, 26.30327], [102.420135, 26.302938], [102.423165, 26.302852], [102.427349, 26.30257], [102.430405, 26.302485], [102.433522, 26.302881], [102.436464, 26.303306], [102.438591, 26.303957], [102.43998, 26.304806], [102.441559, 26.305741], [102.442584, 26.305995], [102.444928, 26.30

# %% [markdown]
# #### 基于矢量数据的统计数据可视化
# 1. 面积可视化
# 2. 人口可视化 （五华114万，盘龙98万，官渡160万，西山96万，东川26万, 呈贡64万，晋宁34万，富民14, 宜良38万，石林24，嵩明41万，禄劝37万, 寻甸46万，安宁48）

# %%
### 利用开源库geopandas打开矢量数据，参考https://geopandas.org/en/stable/
kunming_vec_gpd = gpd.read_file(path_kunming_vec)
kunming_vec_gpd = kunming_vec_gpd.drop(index=0)
kunming_vec_gpd
# Out:
#      fid       name           site  area  \
# 1    2.0      wuhua  www.poi86.com   396
# 2    3.0    panlong  www.poi86.com   845
# 3    4.0     guandu  www.poi86.com   637
# 4    5.0     xishan  www.poi86.com   897
# 5    6.0  dongchuan  www.poi86.com  1865
# 6    7.0  chenggong  www.poi86.com   499
# 7    8.0    jinning  www.poi86.com  1338
# 8    9.0      fumin  www.poi86.com   994
# 9   10.0    yiliang  www.poi86.com  1913
# 10  11.0     shilin  www.poi86.com  1681
# 11  12.0   songming  www.poi86.com   827
# 12  13.0     luquan  www.poi86.com  4229
# 13  14.0    xundian  www.poi86.com  3597
# 14  15.0     anning  www.poi86.com  1299
#
#                                              geometry
# 1   MULTIPOLYGON (((102.69718 25.38032, 102.69726 ...
# 2   MULTIPOLYGON (((102.95160 25.25580, 102.94017 ...
# 3   MULTIPOLYGON (((102.71572 25.03637, 102.71646 ...
# 4   MULTIPOLYGON (((102.55894 25.16249, 102.58745 ...
# 5   MULTIPOLYGON (((102.80190 26.30640, 102.80388 ...
# 6   MULTIPOLYGON (((102.85182 24.70104, 102.85030 ...
# 7   MULTIPOLYGON (((102.73831 24.82029, 102.73989 ...
# 8   MULTIPOLYGON (((102.63295 25.37092, 102.63640 ...
# 9   MULTIPOLYGON (((103.27194 25.26078, 103.27147 ...
# 10  MULTIPOLYGON (((103.66466 24.72727, 103.66353 ...
# 11  MULTIPOLYGON (((102.95160 25.25580, 102.95153 ...
# 12  MULTIPOLYGON (((102.45793 25.43277, 102.45984 ...
# 13  MULTIPOLYGON (((103.54319 25.58692, 103.54139 ...
# 14  MULTIPOLYGON (((102.51505 24.86443, 102.51453 ...

# %%
### 定义pandas.Dataframe()格式的人口数据
population_dict = {'wuhua':114, 'panlong':98, 'guandu':160, 'xishan':26, 'dongchuan':26, 'chenggong':64, 'jinning':34, 'fumin':14, 'yiliang':38, 'shilin':24, 'songming':41, 'luanquan':37, 'xundian':46, 'anning':48}

# %% [markdown]
# #### 地图分级着色folium.Choropleth()
# 参考：https://python-visualization.github.io/folium/modules.html

# %%
map = folium.Map(location=[24.83, 102.84], 
           tiles='https://webst02.is.autonavi.com/appmaptile?style=6&x={x}&y={y}&z={z}',
           attr='高德卫星地图',
           zoom_start=8)

folium.Choropleth(path_kunming_vec,                         #选择json
           data = kunming_vec_gpd,
           columns = ['name','area'],           #列，第一个为key，第二个为value
           key_on = 'feature.properties.name',       #匹配到json
           fill_color = 'PuBu',                 #颜色
           fill_opacity=1,
           legend_name = '面积'                  #图例  
            ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ec158829c596b78a1107bc96c9ce018 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ec158829c596b78a1107bc96c9ce018&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ec158829c596b78a1107bc96c9ce018 = L.map(
#                 &quot;map_4ec158829c596b78a1107bc96c9ce018&quot;,
#                 {
#                     center: [24.83, 102.84],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74bef162b20a1e60ef187741a56dfc47 = L.tileLayer(
#                 &quot;https://webst02.is.autonavi.com/appmaptile?style=6\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7\u536b\u661f\u5730\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4ec158829c596b78a1107bc96c9ce018);
#
#
#             var choropleth_436155abe9538f914fe3db14119d2958 = L.featureGroup(
#                 {}
#             ).addTo(map_4ec158829c596b78a1107bc96c9ce018);
#
#
#         function geo_json_6fd48605668c93ee9bd1d5df45ed5045_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;kunming&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;dongchuan&quot;: case &quot;yiliang&quot;: case &quot;shilin&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a6bddb&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;jinning&quot;: case &quot;anning&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d0d1e6&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;luquan&quot;: case &quot;xundian&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#045a8d&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_6fd48605668c93ee9bd1d5df45ed5045_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6fd48605668c93ee9bd1d5df45ed5045 = L.geoJson(null, {
#                 onEachFeature: geo_json_6fd48605668c93ee9bd1d5df45ed5045_onEachFeature,
#
#                 style: geo_json_6fd48605668c93ee9bd1d5df45ed5045_styler,
#         });
#
#         function geo_json_6fd48605668c93ee9bd1d5df45ed5045_add (data) {
#             geo_json_6fd48605668c93ee9bd1d5df45ed5045
#                 .addData(data)
#                 .addTo(choropleth_436155abe9538f914fe3db14119d2958);
#         }
#             geo_json_6fd48605668c93ee9bd1d5df45ed5045_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[102.235015, 26.188499], [102.235164, 26.188635], [102.236309, 26.1895], [102.23666, 26.189574], [102.238492, 26.190557], [102.24021, 26.192031], [102.241296, 26.194033], [102.242129, 26.19684], [102.242806, 26.199897], [102.243023, 26.204147], [102.243301, 26.209169], [102.243466, 26.214297], [102.243882, 26.215877], [102.244934, 26.217352], [102.246522, 26.218581], [102.249083, 26.21988], [102.25147, 26.220653], [102.252616, 26.221325], [102.253987, 26.222665], [102.255975, 26.223505], [102.257745, 26.223769], [102.260176, 26.224257], [102.262346, 26.224301], [102.265175, 26.223814], [102.268231, 26.223814], [102.272163, 26.223371], [102.276407, 26.223414], [102.281321, 26.223549], [102.284637, 26.223902], [102.288308, 26.224521], [102.292509, 26.225714], [102.297066, 26.228325], [102.299984, 26.22974], [102.302197, 26.230272], [102.306086, 26.230668], [102.309714, 26.230625], [102.311128, 26.230447], [102.312058, 26.230668], [102.312953, 26.231516], [102.313583, 26.232516], [102.314128, 26.234166], [102.314902, 26.234962], [102.316267, 26.235508], [102.320715, 26.237058], [102.322309, 26.237825], [102.326259, 26.239206], [102.328516, 26.240488], [102.329618, 26.240753], [102.33073, 26.240664], [102.33197, 26.24092], [102.33329, 26.241371], [102.336259, 26.243097], [102.339002, 26.244955], [102.340657, 26.24617], [102.342601, 26.246921], [102.344103, 26.247232], [102.345526, 26.247364], [102.347472, 26.247983], [102.349415, 26.249223], [102.351361, 26.251123], [102.353019, 26.25257], [102.354685, 26.254058], [102.358193, 26.258895], [102.359668, 26.260427], [102.361621, 26.261948], [102.363141, 26.264497], [102.365623, 26.268674], [102.367029, 26.270371], [102.369287, 26.2725], [102

# %%
map = folium.Map(location=[24.83, 102.84], 
           tiles='https://webst02.is.autonavi.com/appmaptile?style=6&x={x}&y={y}&z={z}',
           attr='高德卫星地图',
           zoom_start=8)

folium.Choropleth(path_kunming_vec,                         #选择json
           data = population_dict,
           columns = ['name','population'],          #列，第一个为key，第二个为value
           key_on = 'feature.properties.name',       #匹配到json
           fill_color = 'PuBu',                      #颜色
           fill_opacity=1,
           legend_name = '人口'                      #图例  
            ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10796e5a4cdf54e1e52c1891248123c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10796e5a4cdf54e1e52c1891248123c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_10796e5a4cdf54e1e52c1891248123c4 = L.map(
#                 &quot;map_10796e5a4cdf54e1e52c1891248123c4&quot;,
#                 {
#                     center: [24.83, 102.84],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e290b77f2d8567996fe0cad8702c57a = L.tileLayer(
#                 &quot;https://webst02.is.autonavi.com/appmaptile?style=6\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7\u536b\u661f\u5730\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_10796e5a4cdf54e1e52c1891248123c4);
#
#
#             var choropleth_8acb0f14e1b9ee9c032a5a952f5290ff = L.featureGroup(
#                 {}
#             ).addTo(map_10796e5a4cdf54e1e52c1891248123c4);
#
#
#         function geo_json_6126647a42e02d7233f6f48e1d3e4ddc_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;kunming&quot;: case &quot;luquan&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;wuhua&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2b8cbe&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;panlong&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#74a9cf&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;guandu&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#045a8d&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;chenggong&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a6bddb&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;songming&quot;: case &quot;xundian&quot;: case &quot;anning&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d0d1e6&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_6126647a42e02d7233f6f48e1d3e4ddc_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6126647a42e02d7233f6f48e1d3e4ddc = L.geoJson(null, {
#                 onEachFeature: geo_json_6126647a42e02d7233f6f48e1d3e4ddc_onEachFeature,
#
#                 style: geo_json_6126647a42e02d7233f6f48e1d3e4ddc_styler,
#         });
#
#         function geo_json_6126647a42e02d7233f6f48e1d3e4ddc_add (data) {
#             geo_json_6126647a42e02d7233f6f48e1d3e4ddc
#                 .addData(data)
#                 .addTo(choropleth_8acb0f14e1b9ee9c032a5a952f5290ff);
#         }
#             geo_json_6126647a42e02d7233f6f48e1d3e4ddc_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[102.235015, 26.188499], [102.235164, 26.188635], [102.236309, 26.1895], [102.23666, 26.189574], [102.238492, 26.190557], [102.24021, 26.192031], [102.241296, 26.194033], [102.242129, 26.19684], [102.242806, 26.199897], [102.243023, 26.204147], [102.243301, 26.209169], [102.243466, 26.214297], [102.243882, 26.215877], [102.244934, 26.217352], [102.246522, 26.218581], [102.249083, 26.21988], [102.25147, 26.220653], [102.252616, 26.221325], [102.253987, 26.222665], [102.255975, 26.223505], [102.257745, 26.223769], [102.260176, 26.224257], [102.262346, 26.224301], [102.265175, 26.223814], [102.268231, 26.223814], [102.272163, 26.223371], [102.276407, 26.223414], [102.281321, 26.223549], [102.284637, 26.223902], [102.288308, 26.224521], [102.292509, 26.225714], [102.297066, 26.228325], [102.299984, 26.22974], [102.302197, 26.230272], [102.306086, 26.230668], [102.309714, 26.230625], [102.311128, 26.230447], [102.312058, 26.230668], [102.312953, 26.231516], [102.313583, 26.232516], [102.314128, 26.234166], [102.314902, 26.234962], [102.316267, 26.235508], [102.320715, 26.237058], [102.322309, 26.237825], [102.326259, 26.239206], [102.328516, 26.240488], [102.329618, 26.240753], [102.33073, 26.240664], [102.33197, 26.24092], [102.33329, 26.241371], [102.336259, 26.243

# %% [markdown]
# #### 章节作业
# 利用python开源库制作云南大学地标区域（如图书馆、玫瑰园等）线上地图。摇滚地标区域不得少于10处，线上地图简洁规范、信息重复、用户操作体检良好。

# %% [markdown]
# ###
