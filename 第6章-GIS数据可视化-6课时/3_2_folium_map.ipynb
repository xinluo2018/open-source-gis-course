# %% [markdown]
# ### 利用开源制图库folium进行gis数据可视化分析

# %%
import folium
from osgeo import ogr
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd

# %%
path_kunming_vec = 'data/Section-2/kunming_districts.geojson'

# %% [markdown]
# #### 矢量数据显示

# %%
map = folium.Map(location=[24.83, 102.84], 
           tiles='https://webst02.is.autonavi.com/appmaptile?style=6&x={x}&y={y}&z={z}',
           attr='高德卫星地图',
           zoom_start=7)
### 
def style_function(feature):
    return {
        "fillOpacity": 0.5,
        'fillColor': 'green',
        'fillOpacity': 0.2,
        'color': 'blue',
    }
folium.GeoJson(data=path_kunming_vec, 
               tooltip=folium.GeoJsonTooltip(fields=['dt_name']),
               style_function=style_function
               ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07b4ba690911730b68d2ccb3c765bb35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07b4ba690911730b68d2ccb3c765bb35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07b4ba690911730b68d2ccb3c765bb35 = L.map(
#                 &quot;map_07b4ba690911730b68d2ccb3c765bb35&quot;,
#                 {
#                     center: [24.83, 102.84],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34fdc2e97989a3c56853e98ace1c3448 = L.tileLayer(
#                 &quot;https://webst02.is.autonavi.com/appmaptile?style=6\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7\u536b\u661f\u5730\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_07b4ba690911730b68d2ccb3c765bb35);
#
#
#         function geo_json_70c714115f8c37bdbf9a22274085480e_styler(feature) {
#             switch(feature.properties.dt_adcode) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2};
#             }
#         }
#
#         function geo_json_70c714115f8c37bdbf9a22274085480e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_70c714115f8c37bdbf9a22274085480e = L.geoJson(null, {
#                 onEachFeature: geo_json_70c714115f8c37bdbf9a22274085480e_onEachFeature,
#
#                 style: geo_json_70c714115f8c37bdbf9a22274085480e_styler,
#         });
#
#         function geo_json_70c714115f8c37bdbf9a22274085480e_add (data) {
#             geo_json_70c714115f8c37bdbf9a22274085480e
#                 .addData(data)
#                 .addTo(map_07b4ba690911730b68d2ccb3c765bb35);
#         }
#             geo_json_70c714115f8c37bdbf9a22274085480e_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[102.713306, 25.136515], [102.715473, 25.137243], [102.718014, 25.132135], [102.717876, 25.128678], [102.718119, 25.123739], [102.71885, 25.121694], [102.71912, 25.121421], [102.719703, 25.120299], [102.720528, 25.119658], [102.721433, 25.119367], [102.722876, 25.119076], [102.723921, 25.119106], [102.724629, 25.119148], [102.725112, 25.119327], [102.725587, 25.119217], [102.725537, 25.118238], [102.726277, 25.118004], [102.72677, 25.117925], [102.727328, 25.117809], [102.727665, 25.117638], [102.727768, 25.117585], [102.730694, 25.117628], [102.732115, 25.119994], [102.733644, 25.122731], [102.734408, 25.123695], [102.735598, 25.125591], [102.736558, 25.125009], [102.738373, 25.127778], [102.740796, 25.125879], [102.743625, 25.123812], [102.744677, 25.122908], [102.745526, 25.121981], [102.746446, 25.120838], [102.747135, 25.119983], [102.748399, 25.118251], [102.746746, 25.117756], [102.743381, 25.116565], [102.742954, 25.116345], [102.742611, 25.11617], [102.742201, 25.115691], [102.740325, 25.112577], [102.740225, 25.112268], [102.740017, 25.109963], [102.739538, 25.106398], [102.738956, 25.102183], [102.738481, 25.100312], [102.738118, 25.099253], [102.737635, 25.097931], [102.736851, 25.095698], [102.736372, 25.094295], [102.735983, 25.093818], [102.735471, 25.093691], [102.732891, 25.093551], [102.731927, 25.093478], [102.731872, 25.093446], [102.731255, 25.093083], [102.730942, 25.092671], [102.729099, 25.09082], [102.726439, 25.088144], [102.726152, 25.087712], [102.725935, 25.087327], [102.724804, 25.084555], [102.723979, 25.082195], [102.723822, 25.081802], [102.723535, 25.081189], [102.723318, 25.080907], [102.723013, 25.080562], [102.716988, 25.076574], [102.716527, 25.076187], [102.716144, 25.075686], [102.7147, 25.07301], [102.714039, 25.07177], [102.7139, 25.071388], [102.713856, 25.071092], [102.713839, 25.070777], [102.713987, 25.068084], [102.713987, 25.065625], [102.713961, 25.065233], [102.713882, 25.064957], [102.713143, 25.063276], [102.71303, 25.06292], [102.712969, 25.062566], [102.712604, 25.059803], [102.712595, 25.059538], [102.712543, 25.058604], [102.712395, 25.057816], [102.712404, 25.05763], [102.712473, 25.057454], [102.712682, 25.057315], [102.714473, 25.056294], [102.714717, 25.056036], [102.714899, 25.055727], [102.715004, 25.055406], [102.715482, 25.053319], [102.715569, 25.052614], [102.715508, 25.051722], [102.715508, 25.051424], [102.715578, 25.050934], [102.715969, 25.049072], [102.716195, 25.047538], [102.716317, 25.046672], [102.

# %% [markdown]
# #### 基于矢量数据的统计数据可视化
# 1. 面积可视化
# 2. 人口可视化 （五华114万，盘龙98万，官渡160万，西山96万，东川26万, 呈贡64万，晋宁34万，富民14, 宜良38万，石林24，嵩明41万，禄劝37万, 寻甸46万，安宁48）

# %%
### 利用开源库geopandas打开矢量数据，参考https://geopandas.org/en/stable/
kunming_vec_gpd = gpd.read_file(path_kunming_vec)
kunming_vec_gpd = kunming_vec_gpd.drop(index=0)
kunming_vec_gpd
# Out:
#    dt_adcode    dt_name ct_adcode ct_name pr_adcode pr_name cn_adcode  \
# 1     530103        盘龙区    530100     昆明市    530000     云南省    100000
# 2     530111        官渡区    530100     昆明市    530000     云南省    100000
# 3     530112        西山区    530100     昆明市    530000     云南省    100000
# 4     530113        东川区    530100     昆明市    530000     云南省    100000
# 5     530114        呈贡区    530100     昆明市    530000     云南省    100000
# 6     530115        晋宁区    530100     昆明市    530000     云南省    100000
# 7     530124        富民县    530100     昆明市    530000     云南省    100000
# 8     530125        宜良县    530100     昆明市    530000     云南省    100000
# 9     530126    石林彝族自治县    530100     昆明市    530000     云南省    100000
# 10    530127        嵩明县    530100     昆明市    530000     云南省    100000
# 11    530128  禄劝彝族苗族自治县    530100     昆明市    530000     云南省    100000
# 12    530129  寻甸回族彝族自治县    530100     昆明市    530000     云南省    100000
# 13    530181        安宁市    530100     昆明市    530000     云南省    100000
#
#     cn_name  Area                                           geometry
# 1   中华人民共和国   864  MULTIPOLYGON (((102.71668 25.04473, 102.71663 ...
# 2   中华人民共和国   638  MULTIPOLYGON (((102.71717 25.03341, 102.71792 ...
# 3   中华人民共和国   897  MULTIPOLYGON (((102.50726 24.86019, 102.50689 ...
# 4   中华人民共和国  1866  MULTIPOLYGON (((102.80340 26.30291, 102.80537 ...
# 5   中华人民共和国   499  MULTIPOLYGON (((102.85321 24.69792, 102.85168 ...
# 6   中华人民共和国  1338  MULTIPOLYGON (((102.73979 24.81731, 102.74137 ...
# 7   中华人民共和国   994  MULTIPOLYGON (((102.63768 25.36767, 102.64085 ...
# 8   中华人民共和国  1914  MULTIPOLYGON (((103.27379 25.25786, 103.27332 ...
# 9   中华人民共和国  1682  MULTIPOLYGON (((103.66655 24.72420, 103.66542 ...
# 10  中华人民共和国   828  MULTIPOLYGON (((102.95307 25.25274, 102.95301 ...
# 11  中华人民共和国  4225  MULTIPOLYGON (((102.45946 25.42993, 102.46137 ...
# 12  中华人民共和国  3598  MULTIPOLYGON (((103.54505 25.58380, 103.54325 ...
# 13  中华人民共和国  1300  MULTIPOLYGON (((102.26544 24.55692, 102.26724 ...

# %%
### 定义pandas.Dataframe()格式的人口数据
population_dict = {'wuhua':114, 'panlong':98, 'guandu':160, 'xishan':26, 'dongchuan':26, 'chenggong':64, 'jinning':34, 'fumin':14, 'yiliang':38, 'shilin':24, 'songming':41, 'luquan':37, 'xundian':46, 'anning':48}

# %% [markdown]
# #### 地图分级着色folium.Choropleth()
# 参考：https://python-visualization.github.io/folium/modules.html

# %%
map = folium.Map(location=[24.83, 102.84], 
           tiles='https://webst02.is.autonavi.com/appmaptile?style=6&x={x}&y={y}&z={z}',
           attr='高德卫星地图',
           zoom_start=8)

folium.Choropleth(path_kunming_vec,                         #选择json
           data = kunming_vec_gpd,
           columns = ['dt_name','Area'],           #列，第一个为key，第二个为value
           key_on = 'feature.properties.ct_name',       #匹配到json
           fill_color = 'PuBu',                 #颜色
           fill_opacity=1,
           legend_name = '面积'                  #图例  
            ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c61ed8ba3e9debf8de33ad4cdc153fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c61ed8ba3e9debf8de33ad4cdc153fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c61ed8ba3e9debf8de33ad4cdc153fb = L.map(
#                 &quot;map_6c61ed8ba3e9debf8de33ad4cdc153fb&quot;,
#                 {
#                     center: [24.83, 102.84],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8833151dbc224b6dd2256d1e813399d6 = L.tileLayer(
#                 &quot;https://webst02.is.autonavi.com/appmaptile?style=6\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7\u536b\u661f\u5730\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6c61ed8ba3e9debf8de33ad4cdc153fb);
#
#
#             var choropleth_2dadbdb78d3a5b2a8ab3cee7d24ca013 = L.featureGroup(
#                 {}
#             ).addTo(map_6c61ed8ba3e9debf8de33ad4cdc153fb);
#
#
#         function geo_json_30471ba196119913ff722816533bad6f_styler(feature) {
#             switch(feature.properties.dt_adcode) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_30471ba196119913ff722816533bad6f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_30471ba196119913ff722816533bad6f = L.geoJson(null, {
#                 onEachFeature: geo_json_30471ba196119913ff722816533bad6f_onEachFeature,
#
#                 style: geo_json_30471ba196119913ff722816533bad6f_styler,
#         });
#
#         function geo_json_30471ba196119913ff722816533bad6f_add (data) {
#             geo_json_30471ba196119913ff722816533bad6f
#                 .addData(data)
#                 .addTo(choropleth_2dadbdb78d3a5b2a8ab3cee7d24ca013);
#         }
#             geo_json_30471ba196119913ff722816533bad6f_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[102
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10796e5a4cdf54e1e52c1891248123c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10796e5a4cdf54e1e52c1891248123c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_10796e5a4cdf54e1e52c1891248123c4 = L.map(
#                 &quot;map_10796e5a4cdf54e1e52c1891248123c4&quot;,
#                 {
#                     center: [24.83, 102.84],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e290b77f2d8567996fe0cad8702c57a = L.tileLayer(
#                 &quot;https://webst02.is.autonavi.com/appmaptile?style=6\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7\u536b\u661f\u5730\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_10796e5a4cdf54e1e52c1891248123c4);
#
#
#             var choropleth_8acb0f14e1b9ee9c032a5a952f5290ff = L.featureGroup(
#                 {}
#             ).addTo(map_10796e5a4cdf54e1e52c1891248123c4);
#
#
#         function geo_json_6126647a42e02d7233f6f48e1d3e4ddc_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;kunming&quot;: case &quot;luquan&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;wuhua&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2b8cbe&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;panlong&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#74a9cf&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;guandu&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#045a8d&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;chenggong&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a6bddb&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;songming&quot;: case &quot;xundian&quot;: case &quot;anning&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d0d1e6&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_6126647a42e02d7233f6f48e1d3e4ddc_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6126647a42e02d7233f6f48e1d3e4ddc = L.geoJson(null, {
#                 onEachFeature: geo_json_6126647a42e02d7233f6f48e1d3e4ddc_onEachFeature,
#
#                 style: geo_json_6126647a42e02d7233f6f48e1d3e4ddc_styler,
#         });
#
#         function geo_json_6126647a42e02d7233f6f48e1d3e4ddc_add (data) {
#             geo_json_6126647a42e02d7233f6f48e1d3e4ddc
#                 .addData(data)
#                 .addTo(choropleth_8acb0f14e1b9ee9c032a5a952f5290ff);
#         }
#             geo_json_6126647a42e02d7233f6f48e1d3e4ddc_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[102.235015, 26.188499], [102.235164, 26.188635], [102.236309, 26.1895], [102.23666, 26.189574], [102.238492, 26.190557], [102.24021, 26.192031], [102.241296, 26.194033], [102.242129, 26.19684], [102.242806, 26.199897], [102.243023, 26.204147], [102.243301, 26.209169], [102.243466, 26.214297], [102.243882, 26.215877], [102.244934, 26.217352], [102.246522, 26.218581], [102.249083, 26.21988], [102.25147, 26.220653], [102.252616, 26.221325], [102.253987, 26.222665], [102.255975, 26.223505], [102.257745, 26.223769], [102.260176, 26.224257], [102.262346, 26.224301], [102.265175, 26.223814], [102.268231, 26.223814], [102.272163, 26.223371], [102.276407, 26.223414], [102.281321, 26.223549], [102.284637, 26.223902], [102.288308, 26.224521], [102.292509, 26.225714], [102.297066, 26.228325], [102.299984, 26.22974], [102.302197, 26.230272], [102.306086, 26.230668], [102.309714, 26.230625], [102.311128, 26.230447], [102.312058, 26.230668], [102.312953, 26.231516], [102.313583, 26.232516], [102.314128, 26.234166], [102.314902, 26.234962], [102.316267, 26.235508], [102.320715, 26.237058], [102.322309, 26.237825], [102.326259, 26.239206], [102.328516, 26.240488], [102.329618, 26.240753], [102.33073, 26.240664], [102.33197, 26.24092], [102.33329, 26.241371], [102.336259, 26.243

# %% [markdown]
# #### 章节作业
# 利用python开源库制作云南大学地标区域（如图书馆、玫瑰园等）线上地图。摇滚地标区域不得少于10处，线上地图简洁规范、信息重复、用户操作体检良好。

# %% [markdown]
# ###
